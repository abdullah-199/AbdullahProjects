# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/User/Downloads/Automobile.csv")

# %%
print(data)
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
grouped_data = df.groupby("origin")

# %%
print(grouped_data)

# %%
for name,group in grouped_data:
    if name == "japan":
       auto_japan = group
    elif name == "usa":
       auto_usa = group
    else:
       auto_europe = group

# %%
auto_usa
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 392           chevrolet camaro  27.0          4         151.0        90.0
# 393            ford mustang gl  27.0          4         140.0        86.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year origin
# ...

# %%
auto_japan
# Out:
#                       name   mpg  cylinders  displacement  horsepower  weight  \
# 14   toyota corona mark ii  24.0          4         113.0        95.0    2372
# 18            datsun pl510  27.0          4          97.0        88.0    2130
# 29            datsun pl510  27.0          4          97.0        88.0    2130
# 31           toyota corona  25.0          4         113.0        95.0    2228
# 53     toyota corolla 1200  31.0          4          71.0        65.0    1773
# ..                     ...   ...        ...           ...         ...     ...
# 382         toyota corolla  34.0          4         108.0        70.0    2245
# 383            honda civic  38.0          4          91.0        67.0    1965
# 384     honda civic (auto)  32.0          4          91.0        67.0    1965
# 385          datsun 310 gx  38.0          4          91.0        67.0    1995
# 390       toyota celica gt  32.0          4         144.0        96.0    2665
#
# ...

# %%
auto_europe
# Out:
#                              name   mpg  cylinders  displacement  horsepower  \
# 19   volkswagen 1131 deluxe sedan  26.0          4          97.0        46.0
# 20                    peugeot 504  25.0          4         110.0        87.0
# 21                    audi 100 ls  24.0          4         107.0        90.0
# 22                       saab 99e  25.0          4         104.0        95.0
# 23                       bmw 2002  26.0          4         121.0       113.0
# ..                            ...   ...        ...           ...         ...
# 354                   renault 18i  34.5          4         100.0         NaN
# 359     peugeot 505s turbo diesel  28.1          4         141.0        80.0
# 360                  volvo diesel  30.7          6         145.0        76.0
# 375           volkswagen rabbit l  36.0          4         105.0        74.0
# 394                     vw pickup  44.0          4          97.0        52.0
#
# ...

# %%
auto_usa["horsepower"].mean()
# Out:
# 119.04897959183674

# %%
auto_japan["horsepower"].mean()
# Out:
# 79.83544303797468

# %%
auto_europe["horsepower"].mean()
# Out:
# 80.55882352941177

# %%
print("missing values in auto_usa:")
print(auto_usa.isna().sum())
print("missing values in auto_japan:")
print(auto_japan.isna().sum())
print("missing values in auto_europe:")
print(auto_europe.isna().sum())
# Out:
# missing values in auto_usa:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      4
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64
# missing values in auto_japan:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64
# missing values in auto_europe:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      2
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
auto_usa_filled = auto_usa.fillna(auto_usa["horsepower"].mean())
auto_usa_filled
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 392           chevrolet camaro  27.0          4         151.0        90.0
# 393            ford mustang gl  27.0          4         140.0        86.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year origin
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          249 non-null    object
#  1   mpg           249 non-null    float64
#  2   cylinders     249 non-null    int64
#  3   displacement  249 non-null    float64
#  4   horsepower    249 non-null    object
#  5   weight        249 non-null    int64
#  6   acceleration  249 non-null    float64
#  7   model_year    249 non-null    int64
#  8   origin        249 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 19.5+ KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(auto_usa_filled['horsepower'], auto_usa_filled['acceleration'],marker="o")
plt.xlabel("horsepower")
plt.ylabel("acceleration")
plt.title("auto_usa")
plt.grid(True)
plt.show()

plt.scatter(auto_usa_filled['horsepower'], auto_usa_filled['displacement'],marker="o")
plt.xlabel("horsepower")
plt.ylabel("displacement")
plt.title("auto_usa")
plt.grid(True)
plt.show()

# %%
plt.scatter(auto_japan['horsepower'], auto_japan['acceleration'],marker="o")
plt.xlabel("horsepower")
plt.ylabel("acceleration")
plt.title("auto_japan")
plt.grid(True)
plt.show()

plt.scatter(auto_japan['horsepower'], auto_japan['displacement'],marker="o")
plt.xlabel("horsepower")
plt.ylabel("displacement")
plt.title("auto_japan")
plt.grid(True)
plt.show()

# %%
plt.scatter(auto_europe['horsepower'], auto_europe['acceleration'],marker="o")
plt.xlabel("horsepower")
plt.ylabel("acceleration")
plt.title("auto_europe")
plt.grid(True)
plt.show()

plt.scatter(auto_europe['horsepower'], auto_europe['displacement'],marker="o")
plt.xlabel("horsepower")
plt.ylabel("displacement")
plt.title("auto_europe")
plt.grid(True)
plt.show()
